# %%
import pandas as pd

# %%
keywords_df = pd.read_csv('data\\Keyword_NLP.csv')
distilbert_df = pd.read_csv('data\\Emotion NLP\\results\\distilbert-journal_predictions.csv')
roberta_df = pd.read_csv('data\\Emotion NLP\\results\\roberta-journal_predictions.csv')

# %%
keywords_df
# Out:
#                                                  text  \
# 0   Today felt heavier than I expected. I kept rep...
# 1   I noticed how tense my body felt this morning....
# 2   Writing this down helps a little. The thoughts...
# 3   I felt frustrated during the session, but I di...
# 4   There was a moment today where I felt calm. It...
# 5   I keep thinking about the past and how differe...
# 6   I felt tired even after sleeping. Emotionally ...
# 7   I noticed a pattern in my reactions today. I g...
# 8   Some feelings are hard to name. I know somethi...
# 9   Ending the day with writing feels grounding. I...
# 10  I caught myself overthinking small interaction...
# 11  It felt uncomfortable to sit with my emotions ...
# 12  There was a sense of restlessness throughout t...
# 13  I felt disconnected during conversations, as i...
# 14  Part of me wanted reassurance, but another par...
# 15  I noticed how quickly my mood shifted when pla...
# 16  Today wasn't terrible, but it also wasn't good...
# 17  I kept comparing how I feel now to how I used ...
# 18  There was a quiet sense of relief when I final...
# 19  I'm not sure what I was feeling exactly, just ...
#
#                                      keybert_keywords  \
# 0   ['felt heavier', 'heavier expected', 'heavier'...
# 1   ['slow breathing', 'felt morning', 'tense body...
# 2   ['thoughts feel', 'writing helps', 'thoughts',...
# 3   ['felt frustrated', 'frustrated session', 'fru...
# 4   ['felt calm', 'calm possible', 'reminded calm'...
# 5   ['thinking past', 'past different', 'past', 't...
# 6   ['felt tired', 'emotionally drained', 'sleepin...
# 7   ['feel misunderstood', 'defensive feel', 'defe...
# 8   ['feelings hard', 'feelings', 'hard', 'quite e...
# 9   ['writing feels', 'day writing', 'ending day',...
# 10  ['small interactions', 'interactions today', '...
# 11  ['sit emotions', 'felt uncomfortable', 'uncomf...
# 12  ['sense restlessness', 'restlessness day', 're...
# 13  ['disconnected conversations', 'felt disconnec...
# 14  ['wanted reassurance', 'reassurance didn', 're...
# 15  ['mood shifted', 'quickly mood', 'mood', 'shif...
# 16  ['felt flat', 'terrible wasn', 'wasn terrible'...
# 17  ['comparing feel', 'things heavier', 'used fee...
# 18  ['relief finally', 'sense relief', 'relief', '...
# 19  ['feeling exactly', 'feeling', 'longer expecte...
#
#                                         keybert_best  \
# 0                                   ['conversation']
# 1                   ['slow breathing', 'tense body']
# 2                                       ['thoughts']
# 3                             ['frustrated session']
# 4                                           ['calm']
# 5                                                 []
# 6                                 ['tired sleeping']
# 7   ['defensive feel', 'defensive', 'misunderstood']
# 8                                       ['feelings']
# 9                                                 []
# 10                            ['small interactions']
# 11                             ['uncomfortable sit']
# 12                                  ['restlessness']
# 13                    ['disconnected conversations']
# 14                                   ['reassurance']
# 15                                          ['mood']
# 16                                 ['terrible wasn']
# 17                                                []
# 18                             ['relief', 'evening']
# 19                                                []
#
#                                         yake_keywords  \
# 0   ['today felt', 'felt heavier', 'today', 'expec...
# 1   ['body felt', 'morning', 'noticed', 'tense', '...
# 2   ['writing', 'head', 'thoughts', 'feel', 'loud'...
# 3   ['felt frustrated', 'session', 'loud', 'held b...
# 4   ['moment today', 'felt calm', 'calm', 'moment'...
# 5    ['choice', 'thinking', 'past', 'things', 'made']
# 6   ['felt tired', 'sleeping', 'emotionally draine...
# 7   ['reactions today', 'today', 'feel misundersto...
# 8                     ['feelings', 'hard', 'explain']
# 9   ['feels grounding', 'writing feels', 'ending',...
# 10  ['interactions today', 'bad happened', 'overth...
# 11  ['felt uncomfortable', 'felt', 'uncomfortable'...
# 12  ['fully settle', 'day', 'sense', 'restlessness...
# 13  ['felt disconnected', 'conversations', 'felt',...
# 14  ['wanted reassurance', 'reassurance', 'part', ...
# 15  ['changed unexpectedly', 'mood shifted', 'plan...
# 16  ['today', 'terrible', 'good', 'felt flat', 'fl...
# 17  ['things heavier', 'made things', 'feel', 'hea...
# 18  ['quiet sense', 'evening', 'quiet', 'sense', '...
# 19        ['expected', 'feeling', 'stayed', 'longer']
#
#                                             yake_best
# 0                   ['today', 'head', 'conversation']
# 1                    ['morning', 'body', 'shoulders']
# 2                       ['head', 'thoughts', 'paper']
# 3                                         ['session']
# 4                         ['calm', 'moment', 'today']
# 5                                ['choice', 'things']
# 6                                                  []
# 7   ['today', 'pattern', 'reactions', 'misundersto...
# 8                                        ['feelings']
# 9                                    ['day', 'sense']
# 10                    ['small interactions', 'today']
# 11                                       ['emotions']
# 12                   ['day', 'sense', 'restlessness']
# 13                                  ['conversations']
# 14                            ['reassurance', 'part']
# 15                                  ['mood', 'plans']
# 16                                          ['today']
# 17                                         ['things']
# 18       ['quiet sense', 'evening', 'relief', 'time']
# 19                                                 []

# %%
distilbert_df
# Out:
#                                                  text  prob_sadness  \
# 0   Today felt heavier than I expected. I kept rep...      0.746744
# 1   I noticed how tense my body felt this morning....      0.328351
# 2   Writing this down helps a little. The thoughts...      0.599115
# 3   I felt frustrated during the session, but I di...      0.228962
# 4   There was a moment today where I felt calm. It...      0.209495
# 5   I keep thinking about the past and how differe...      0.746651
# 6   I felt tired even after sleeping. Emotionally ...      0.999084
# 7   I noticed a pattern in my reactions today. I g...      0.940122
# 8   Some feelings are hard to name. I know somethi...      0.582452
# 9   Ending the day with writing feels grounding. I...      0.487708
# 10  I caught myself overthinking small interaction...      0.302303
# 11  It felt uncomfortable to sit with my emotions ...      0.157869
# 12  There was a sense of restlessness throughout t...      0.224494
# 13  I felt disconnected during conversations, as i...      0.936649
# 14  Part of me wanted reassurance, but another par...      0.567244
# 15  I noticed how quickly my mood shifted when pla...      0.383343
# 16  Today wasn't terrible, but it also wasn't good...      0.909197
# 17  I kept comparing how I feel now to how I used ...      0.965703
# 18  There was a quiet sense of relief when I final...      0.993727
# 19  I'm not sure what I was feeling exactly, just ...      0.213977
#
# 15        0.287789               0      0.775737             1       0.023281
# 16        0.633888               1      0.961519             1       0.018392
# 17        0.399000               0      0.793389             1       0.012062
# 18        0.039048               0      0.354979             0       0.013768
# 19        0.193014               0      0.344961             0       0.281043
#
#     pred_surprise  prob_trust  pred_trust
# 0               0    0.011891           0
# 1               0    0.012024           0
# 2               0    0.124632           0
# 3               0    0.005390           0
# 4               0    0.162927           0
# 5               0    0.047497           0
# 6               0    0.010380           0
# 7               0    0.034782           0
# 8               0    0.035757           0
# 9               0    0.135452           0
# 10              0    0.041025           0
# 11              0    0.032214           0
# 12              0    0.011067           0
# 13              0    0.008265           0
# 14              0    0.019939           0
# 15              0    0.058288           0
# 16              0    0.007183           0
# 17              0    0.021713           0
# 18              0    0.041196           0
# 19              0    0.022445           0
#
# [20 rows x 23 columns]

# %%
def select_theme_keywords(row):
  # convert list string to list
  row["yake_best"] = row["yake_best"].strip("[]").replace("'", "").split(", ")
  # if row["keybert_best"]:
  #   return row["keybert_best"]
  if row["yake_best"][0]:
    return row["yake_best"]
  return []

# %%
def format_theme(keywords):
  if not keywords:
    return "the described experience"
  if len(keywords) == 1:
    return 'their ' + keywords[0]
  return 'their ' + ", ".join(keywords)

# %%
# lightweight linguistic detectors
UNCERTAINTY_PHRASES = [
  "not sure", "hard to name", "can't explain", "cannot explain",
  "something is there", "difficult to explain"
]

COPING_VERBS = [
  "writing", "reflecting", "reflection", "breathing",
  "grounding", "sitting with", "slowing"
]

SOMATIC_TERMS = [
  "body", "shoulders", "breathing", "tight",
  "tense", "restless", "tension"
]

SELF_REFLECTIVE_PHRASES = [
  "i noticed", "i realized", "i caught myself",
  "pattern in my reactions", "i keep noticing"
]

# %%
def contains_any(text, phrase_list):
  text = text.lower()
  return any(p in text for p in phrase_list)

def count_any(text, phrase_list):
  text = text.lower()
  return sum(p in text for p in phrase_list)

# %%
def get_emotion_probs(row):
  return {
    "sadness": row["prob_sadness"],
    "joy": row["prob_joy"],
    "love": row["prob_love"],
    "anger": row["prob_anger"],
    "fear": row["prob_fear"],
    "surprise": row["prob_surprise"]
  }

# %%
def detect_insights(row):
  emotions = get_emotion_probs(row)
  text = row["text"]

  insights = []

  # Emotional Load
  mean_neg = (emotions["sadness"] + emotions["fear"]) / 2
  if mean_neg > 0.6:
    insights.append("Emotional Load")

  # Emotional Clarity vs Ambiguity
  if count_any(text, UNCERTAINTY_PHRASES) >= 1:
    insights.append("Emotional Clarity vs Ambiguity")

  # Regulation & Coping
  if contains_any(text, COPING_VERBS):
    insights.append("Regulation & Coping Mode")

  # Arousal / Restlessness
  if (emotions["fear"] + emotions["anger"] > 0.6 or
      contains_any(text, SOMATIC_TERMS)):
    insights.append("Arousal / Restlessness Level")

  # Self-Relation & Appraisal
  if contains_any(text, SELF_REFLECTIVE_PHRASES):
    insights.append("Self-Relation & Appraisal")

  return insights

# %%
TEMPLATES = {
  "Emotional Load": [
    "This entry suggests a relatively high emotional load, particularly in relation to {theme}.",
    "The overall tone of this entry indicates emotional heaviness connected to {theme}."
  ],
  "Emotional Clarity vs Ambiguity": [
    "The feelings described here appear difficult to clearly define, especially around {theme}.",
    "This entry reflects some uncertainty or ambiguity in how emotions related to {theme} are understood."
  ],
  "Regulation & Coping Mode": [
    "This entry highlights an active attempt to regulate emotions through reflection, particularly in response to {theme}.",
    "The writer appears to be engaging in a coping process while thinking about {theme}."
  ],
  "Arousal / Restlessness Level": [
    "The language used suggests heightened internal activation or restlessness related to {theme}.",
    "This entry reflects a state of tension or agitation associated with {theme}."
  ],
  "Self-Relation & Appraisal": [
    "This entry shows reflective self-evaluation in relation to {theme}.",
    "The writer appears to be assessing their own reactions or patterns while considering {theme}."
  ]
}

# %%
distilbert_emot_keywords_df = distilbert_df.merge(keywords_df)

# %%
roberta_emot_keywords_df = roberta_df.merge(keywords_df)

# %%
import random

def generate_insight_sentences(row):
  themes = select_theme_keywords(row)
  theme_text = format_theme(themes)

  categories = detect_insights(row)
  outputs = []
  
  if not categories:
    outputs.append({
      "category": "No Insights Detected",
      "text": "No significant emotional insights were detected in this entry."
    })
    return outputs
  
  for cat in categories:
    template = random.choice(TEMPLATES[cat])
    outputs.append({
      "category": cat,
      "text": template.format(theme=theme_text)
    })

  return outputs

# %%
distilbert_emot_keywords_df["insights"] = distilbert_emot_keywords_df.apply(generate_insight_sentences, axis=1)
roberta_emot_keywords_df["insights"] = roberta_emot_keywords_df.apply(generate_insight_sentences, axis=1)

# %%
# print text and insight
for index, row in roberta_emot_keywords_df.iterrows():
  print(row['text'])
  for insight in row['insights']:
    print(insight)
  print()
# Out:
# Today felt heavier than I expected. I kept replaying the conversation in my head, wondering if I said too much or not enough.
# {'category': 'Emotional Load', 'text': 'This entry suggests a relatively high emotional load, particularly in relation to their today, head, conversation.'}
# {'category': 'Arousal / Restlessness Level', 'text': 'This entry reflects a state of tension or agitation associated with their today, head, conversation.'}
#
# I noticed how tense my body felt this morning. My shoulders were tight, and I struggled to slow my breathing.
# {'category': 'Emotional Load', 'text': 'The overall tone of this entry indicates emotional heaviness connected to their morning, body, shoulders.'}
# {'category': 'Regulation & Coping Mode', 'text': 'The writer appears to be engaging in a coping process while thinking about their morning, body, shoulders.'}
# {'category': 'Arousal / Restlessness Level', 'text': 'This entry reflects a state of tension or agitation associated with their morning, body, shoulders.'}
# {'category': 'Self-Relation & Appraisal', 'text': 'The writer appears to be assessing their own reactions or patterns while considering their morning, body, shoulders.'}
#
# Writing this down helps a little. The thoughts feel less loud when they exist on paper instead of just in my head.
# {'category': 'Regulation & Coping Mode', 'text': 'The writer appears to be engaging in a coping process while thinking about their head, thoughts, paper.'}
#
# I felt frustrated during the session, but I didn't say it out loud. I'm not sure why I held back.
# {'category': 'Emotional Clarity vs Ambiguity', 'text': 'This entry reflects some uncertainty or ambiguity in how emotions related to their session are understood.'}
# {'category': 'Arousal / Restlessness Level', 'text': 'The language used suggests heightened internal activation or restlessness related to their session.'}
#
# There was a moment today where I felt calm. It didn't last long, but it reminded me that calm is still possible.
# {'category': 'No Insights Detected', 'text': 'No significant emotional insights were detected in this entry.'}
#
# I keep thinking about the past and how different things might have been if I had made another choice.
# {'category': 'No Insights Detected', 'text': 'No significant emotional insights were detected in this entry.'}
#
# I felt tired even after sleeping. Emotionally drained is the only way I can describe it.
# {'category': 'No Insights Detected', 'text': 'No significant emotional insights were detected in this entry.'}
#
# I noticed a pattern in my reactions today. I get defensive when I feel misunderstood.
# {'category': 'Arousal / Restlessness Level', 'text': 'This entry reflects a state of tension or agitation associated with their today, pattern, reactions, misunderstood, defensive.'}
# {'category': 'Self-Relation & Appraisal', 'text': 'This entry shows reflective self-evaluation in relation to their today, pattern, reactions, misunderstood, defensive.'}
#
# Some feelings are hard to name. I know something is there, but I can't quite explain it.
# {'category': 'Emotional Clarity vs Ambiguity', 'text': 'This entry reflects some uncertainty or ambiguity in how emotions related to their feelings are understood.'}
#
# Ending the day with writing feels grounding. It helps me make sense of everything that happened.
# {'category': 'Regulation & Coping Mode', 'text': 'The writer appears to be engaging in a coping process while thinking about their day, sense.'}
#
# I caught myself overthinking small interactions today, even though nothing objectively bad happened.
# {'category': 'Self-Relation & Appraisal', 'text': 'This entry shows reflective self-evaluation in relation to their small interactions, today.'}
#
# It felt uncomfortable to sit with my emotions instead of distracting myself, but I tried anyway.
# {'category': 'No Insights Detected', 'text': 'No significant emotional insights were detected in this entry.'}
#
# There was a sense of restlessness throughout the day, like I couldn't fully settle into anything.
# {'category': 'Emotional Load', 'text': 'This entry suggests a relatively high emotional load, particularly in relation to their day, sense, restlessness.'}
# {'category': 'Arousal / Restlessness Level', 'text': 'This entry reflects a state of tension or agitation associated with their day, sense, restlessness.'}
#
# I felt disconnected during conversations, as if I was present but not really there.
# {'category': 'No Insights Detected', 'text': 'No significant emotional insights were detected in this entry.'}
#
# Part of me wanted reassurance, but another part didn't want to ask for it.
# {'category': 'No Insights Detected', 'text': 'No significant emotional insights were detected in this entry.'}
#
# I noticed how quickly my mood shifted when plans changed unexpectedly.
# {'category': 'Self-Relation & Appraisal', 'text': 'This entry shows reflective self-evaluation in relation to their mood, plans.'}
#
# Today wasn't terrible, but it also wasn't good. It just felt flat.
# {'category': 'No Insights Detected', 'text': 'No significant emotional insights were detected in this entry.'}
#
# I kept comparing how I feel now to how I used to feel, and that made things heavier.
# {'category': 'No Insights Detected', 'text': 'No significant emotional insights were detected in this entry.'}
#
# There was a quiet sense of relief when I finally had time alone this evening.
# {'category': 'No Insights Detected', 'text': 'No significant emotional insights were detected in this entry.'}
#
# I'm not sure what I was feeling exactly, just that it stayed with me longer than I expected.
# {'category': 'Emotional Clarity vs Ambiguity', 'text': 'This entry reflects some uncertainty or ambiguity in how emotions related to the described experience are understood.'}
